# %%
import pandas as pd
import numpy as np

dict1={'Names':['Ramesh','Suresh','Sathish',np.nan],
       'Age':[np.nan,22,24,26],
      'City':['Hyd','Blr',np.nan,'Vizag']}
d1=pd.DataFrame(dict1)
d1.to_csv('data1.csv',index=False)

# %%
import pandas as pd
import numpy as np

dict2={'Names':['Ramesh','Suresh','Sathish',None],
       'Age':[None,22,24,26],
      'City':['Hyd','Blr',None,'Vizag']}
d2=pd.DataFrame(dict2)
d2.to_csv('data2.csv',index=False)

# %%
d1.isnull()
# Out:
#    Names    Age   City
# 0  False   True  False
# 1  False  False  False
# 2  False  False   True
# 3   True  False  False

# %%
d1.isnull().sum()
# Out:
# Names    1
# Age      1
# City     1
# dtype: int64

# %% [markdown]
# **Difference between NAN and None**

# %% [markdown]
# - For **Object Type** we use **None**
#
# - For **Number Type** we will use **NAN**

# %%
np.nan+5
# Out:
# nan

# %%
None+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 None+5
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
arr1=np.array([1,2,3,np.nan])
arr2=np.array([1,2,3,None])
arr1
# Out:
# array([ 1.,  2.,  3., nan])

# %%
arr2
# Out:
# array([1, 2, 3, None], dtype=object)

# %%
arr1.dtype,arr2.dtype
# Out:
# (dtype('float64'), dtype('O'))

# %%
np.sum(arr1),np.nansum(arr1)
#1+2+3+mp.nam     1+2+3
# Out:
# (np.float64(nan), np.float64(6.0))

# %%
np.sum(arr2) # error because of object type
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 np.sum(arr2)
#
# File D:\anaconda3\Lib\site-packages\numpy\_core\fromnumeric.py:2485, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2482         return out
#    2483     return res
# -> 2485 return _wrapreduction(
#    2486     a, np.add, 'sum', axis, dtype, out,
#    2487     keepdims=keepdims, initial=initial, where=where
#    2488 )
#
# File D:\anaconda3\Lib\site-packages\numpy\_core\fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %%
arr2 # object type this is my mistake
# how can we convert into float type
# Out:
# array([1, 2, 3, None], dtype=object)

# %% [markdown]
# **astype**

# %%
arr3=arr2.astype(float) 
arr3
# Out:
# array([ 1.,  2.,  3., nan])

# %%
d2['Age'].values.astype(int) # to convert to another data type completely
# Out:
# C:\Users\91801\AppData\Local\Temp\ipykernel_14024\3751503362.py:1: RuntimeWarning: invalid value encountered in cast
#   d2['Age'].values.astype(int)
# array([-9223372036854775808,                   22,                   24,
#                          26])

# %% [markdown]
# **Fill with a random value**

# %%
d1.fillna(30) # bad approach not recommended because names also filled with 30
# inplace=True
# Out:
#      Names   Age   City
# 0   Ramesh  30.0    Hyd
# 1   Suresh  22.0    Blr
# 2  Sathish  24.0     30
# 3       30  26.0  Vizag

# %%
d1
# Out:
#      Names   Age   City
# 0   Ramesh   NaN    Hyd
# 1   Suresh  22.0    Blr
# 2  Sathish  24.0    NaN
# 3      NaN  26.0  Vizag

# %% [markdown]
# **fill with a random value based on column**

# %%
# based on the column we fill it
# first select the colums
d1['Age'].fillna(30)
#d1['Age']=d1['Age'].fillna(30)
# Out:
# 0    30.0
# 1    22.0
# 2    24.0
# 3    26.0
# Name: Age, dtype: float64

# %% [markdown]
# **By using methods**
#
# - pad
#
# - ffill
#
# - bfill
#
# - backfill

# %%
d1.fillna(method='pad')
# Out:
# C:\Users\91801\AppData\Local\Temp\ipykernel_14024\3282249208.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   d1.fillna(method='pad')
#      Names   Age   City
# 0   Ramesh   NaN    Hyd
# 1   Suresh  22.0    Blr
# 2  Sathish  24.0    Blr
# 3  Sathish  26.0  Vizag

# %%
# to ignore the warnings
import warnings
warnings.filterwarnings('ignore')
d1.fillna(method='pad')
# Out:
#      Names   Age   City
# 0   Ramesh   NaN    Hyd
# 1   Suresh  22.0    Blr
# 2  Sathish  24.0    Blr
# 3  Sathish  26.0  Vizag

# %%
d1
# Out:
#      Names   Age   City
# 0   Ramesh   NaN    Hyd
# 1   Suresh  22.0    Blr
# 2  Sathish  24.0    NaN
# 3      NaN  26.0  Vizag

# %%
d1.fillna(method='pad',axis=0)
# Out:
#      Names   Age   City
# 0   Ramesh   NaN    Hyd
# 1   Suresh  22.0    Blr
# 2  Sathish  24.0    Blr
# 3  Sathish  26.0  Vizag

# %%
d1.fillna(method='ffill')
# Out:
#      Names   Age   City
# 0   Ramesh   NaN    Hyd
# 1   Suresh  22.0    Blr
# 2  Sathish  24.0    Blr
# 3  Sathish  26.0  Vizag

# %%
d1.fillna(method='bfill')
# Out:
#      Names   Age   City
# 0   Ramesh  22.0    Hyd
# 1   Suresh  22.0    Blr
# 2  Sathish  24.0  Vizag
# 3      NaN  26.0  Vizag

# %%
d1.fillna(method='backfill')
# Out:
#      Names   Age   City
# 0   Ramesh  22.0    Hyd
# 1   Suresh  22.0    Blr
# 2  Sathish  24.0  Vizag
# 3      NaN  26.0  Vizag

# %% [markdown]
# **Mean-Median-Mode**

# %% [markdown]
# - when data has outliers go with **Median**
#
# - Otherwise fill with **Mean**
#
# - For a categorical data fill with **Mode**

# %%
age_mean=d1['Age'].mean()
d1['Age'].fillna(age_mean)
# Out:
# 0    24.0
# 1    22.0
# 2    24.0
# 3    26.0
# Name: Age, dtype: float64

# %%
0d1['City'].mode()
# Out:
# 0      Blr
# 1      Hyd
# 2    Vizag
# Name: City, dtype: object

# %%
len(d1)
# Out:
# 4

# %%
new_row={'Names':'Sathish','Age':24,'City':'Vizag'}
d1.loc[len(d1)]=new_row
d1
# Out:
#      Names   Age   City
# 0   Ramesh   NaN    Hyd
# 1   Suresh  22.0    Blr
# 2  Sathish  24.0    NaN
# 3      NaN  26.0  Vizag
# 4  Sathish  24.0  Vizag
# 5  Sathish  24.0  Vizag

# %%
d1['City'].mode().values[0]
# Out:
# 'Vizag'

# %%
d1  # df
d1['City'] # select the data
d1['City'].mode()
d1['City'].mode().values  # series will come if uu use values
city_mode=d1['City'].mode().values[0]
d1['City'].fillna(city_mode)
# Out:
# 0      Hyd
# 1      Blr
# 2    Vizag
# 3    Vizag
# 4    Vizag
# 5    Vizag
# Name: City, dtype: object

# %%
d1['Age'].mean()
# Out:
# np.float64(24.0)
